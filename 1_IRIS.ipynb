# %% [markdown]
# The Iris flower data set is an example of an open data. It is also called Fisher's Iris data set as this data set was introduced by the British statistician and biologist Ronald Fisher in 1936. The Iris data set consists of 50 samples from each of the three species of the flower Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured for each sample: the length and the width of the sepals and petals, in centimeters. Based on the combination of these four features, Fisher developed a model to distinguish one species from each other. The full data set is freely available on UCI Machine Learning Repository at https://archive.ics.uci.edu/ml/datasets/iris.
#
# The header is : sepal length, sepal width, petal length, petal width, iris, Species No. It has  value 1 for Iris setosa, 2 for Iris virginica and 3 for Iris versicolor.

# %% [markdown]
# 1. Load the data in the file Iris.txt in a 2-D array called iris.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
print(iris)
# Out:
# [['5.1' '3.5' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.0' '1.4' '0.2' 'Iris-setosa']
#  ['4.7' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['4.6' '3.1' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.6' '1.4' '0.2' 'Iris-setosa']
#  ['5.4' '3.9' '1.7' '0.4' 'Iris-setosa']
#  ['4.6' '3.4' '1.4' '0.3' 'Iris-setosa']
#  ['5.0' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['4.4' '2.9' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.4' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['4.8' '3.4' '1.6' '0.2' 'Iris-setosa']
#  ['4.8' '3.0' '1.4' '0.1' 'Iris-setosa']
#  ['4.3' '3.0' '1.1' '0.1' 'Iris-setosa']
#  ['5.8' '4.0' '1.2' '0.2' 'Iris-setosa']
#  ['5.7' '4.4' '1.5' '0.4' 'Iris-setosa']
#  ['5.4' '3.9' '1.3' '0.4' 'Iris-setosa']
#  ['5.1' '3.5' '1.4' '0.3' 'Iris-setosa']
#  ['5.7' '3.8' '1.7' '0.3' 'Iris-setosa']
#  ['5.1' '3.8' '1.5' '0.3' 'Iris-setosa']
#  ['5.4' '3.4' '1.7' '0.2' 'Iris-setosa']
#  ['5.1' '3.7' '1.5' '0.4' 'Iris-setosa']
#  ['4.6' '3.6' '1.0' '0.2' 'Iris-setosa']
# ...

# %% [markdown]
# 2. Drop column whose index = 4 from the array iris.

# %%
import numpy as np
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
iris=iris[:,:4]
print(iris)
# Out:
# [['5.1' '3.5' '1.4' '0.2']
#  ['4.9' '3.0' '1.4' '0.2']
#  ['4.7' '3.2' '1.3' '0.2']
#  ['4.6' '3.1' '1.5' '0.2']
#  ['5.0' '3.6' '1.4' '0.2']
#  ['5.4' '3.9' '1.7' '0.4']
#  ['4.6' '3.4' '1.4' '0.3']
#  ['5.0' '3.4' '1.5' '0.2']
#  ['4.4' '2.9' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.4' '3.7' '1.5' '0.2']
#  ['4.8' '3.4' '1.6' '0.2']
#  ['4.8' '3.0' '1.4' '0.1']
#  ['4.3' '3.0' '1.1' '0.1']
#  ['5.8' '4.0' '1.2' '0.2']
#  ['5.7' '4.4' '1.5' '0.4']
#  ['5.4' '3.9' '1.3' '0.4']
#  ['5.1' '3.5' '1.4' '0.3']
#  ['5.7' '3.8' '1.7' '0.3']
#  ['5.1' '3.8' '1.5' '0.3']
#  ['5.4' '3.4' '1.7' '0.2']
#  ['5.1' '3.7' '1.5' '0.4']
#  ['4.6' '3.6' '1.0' '0.2']
#  ['5.1' '3.3' '1.7' '0.5']
#  ['4.8' '3.4' '1.9' '0.2']
#  ['5.0' '3.0' '1.6' '0.2']
#  ['5.0' '3.4' '1.6' '0.4']
#  ['5.2' '3.5' '1.5' '0.2']
#  ['5.2' '3.4' '1.4' '0.2']
#  ['4.7' '3.2' '1.6' '0.2']
#  ['4.8' '3.1' '1.6' '0.2']
#  ['5.4' '3.4' '1.5' '0.4']
#  ['5.2' '4.1' '1.5' '0.1']
#  ['5.5' '4.2' '1.4' '0.2']
# ...

# %% [markdown]
# 3. Display the shape, dimensions and size of iris.

# %%
import numpy as np
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
print("Shape:",np.shape(iris))
print("Dimensions:",np.ndim(iris))
print("Size:",np.size(iris))
# Out:
# Shape: (150, 5)
# Dimensions: 2
# Size: 750

# %% [markdown]
# 4. Split iris into three 2-D arrays, each array for a different species. Call them irisl, iris2, iris3.

# %%
import numpy as np
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
spc_num=iris[:,4]
#iris1
iris1=iris[spc_num=='Iris-setosa',:4]
#iris2
iris2=iris[spc_num=='Iris-versicolor',:4]
#iris3
iris3=iris[spc_num=='Iris-virginica',:4]

# %% [markdown]
# 5. Print the three arrays irisl, iris2, iris3

# %%
print("\tIRIS 1\n")
print(iris1)
print("\n\tIRIS 2\n")
print(iris2)
print("\n\tIRIS 3\n")
print(iris3)
# Out:
# 	IRIS 1
#
# [['5.1' '3.5' '1.4' '0.2']
#  ['4.9' '3.0' '1.4' '0.2']
#  ['4.7' '3.2' '1.3' '0.2']
#  ['4.6' '3.1' '1.5' '0.2']
#  ['5.0' '3.6' '1.4' '0.2']
#  ['5.4' '3.9' '1.7' '0.4']
#  ['4.6' '3.4' '1.4' '0.3']
#  ['5.0' '3.4' '1.5' '0.2']
#  ['4.4' '2.9' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.4' '3.7' '1.5' '0.2']
#  ['4.8' '3.4' '1.6' '0.2']
#  ['4.8' '3.0' '1.4' '0.1']
#  ['4.3' '3.0' '1.1' '0.1']
#  ['5.8' '4.0' '1.2' '0.2']
#  ['5.7' '4.4' '1.5' '0.4']
#  ['5.4' '3.9' '1.3' '0.4']
#  ['5.1' '3.5' '1.4' '0.3']
#  ['5.7' '3.8' '1.7' '0.3']
#  ['5.1' '3.8' '1.5' '0.3']
#  ['5.4' '3.4' '1.7' '0.2']
#  ['5.1' '3.7' '1.5' '0.4']
#  ['4.6' '3.6' '1.0' '0.2']
#  ['5.1' '3.3' '1.7' '0.5']
#  ['4.8' '3.4' '1.9' '0.2']
#  ['5.0' '3.0' '1.6' '0.2']
#  ['5.0' '3.4' '1.6' '0.4']
#  ['5.2' '3.5' '1.5' '0.2']
#  ['5.2' '3.4' '1.4' '0.2']
#  ['4.7' '3.2' '1.6' '0.2']
#  ['4.8' '3.1' '1.6' '0.2']
#  ['5.4' '3.4' '1.5' '0.4']
#  ['5.2' '4.1' '1.5' '0.1']
#  ['5.5' '4.2' '1.4' '0.2']
# ...

# %% [markdown]
# 6. Create a 1-D array header having elements "sepal length", "sepal width", "petal length", "petal width", "Species No" in that order

# %%
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
header = np.array(["sepal length", "sepal width", "petal length", "petal width", "Species No"])

# %% [markdown]
# 7. Display the array header.

# %%
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
header = np.array(["sepal length", "sepal width", "petal length", "petal width", "Species No"])
iris=np.insert(iris,0,header,axis=0)
print(iris)
# Out:
# [['sepal length' 'sepal width' 'petal length' 'petal width' 'Species No']
#  ['5.1' '3.5' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.0' '1.4' '0.2' 'Iris-setosa']
#  ['4.7' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['4.6' '3.1' '1.5' '0.2' 'Iris-setosa']
#  ['5.0' '3.6' '1.4' '0.2' 'Iris-setosa']
#  ['5.4' '3.9' '1.7' '0.4' 'Iris-setosa']
#  ['4.6' '3.4' '1.4' '0.3' 'Iris-setosa']
#  ['5.0' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['4.4' '2.9' '1.4' '0.2' 'Iris-setosa']
#  ['4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['5.4' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['4.8' '3.4' '1.6' '0.2' 'Iris-setosa']
#  ['4.8' '3.0' '1.4' '0.1' 'Iris-setosa']
#  ['4.3' '3.0' '1.1' '0.1' 'Iris-setosa']
#  ['5.8' '4.0' '1.2' '0.2' 'Iris-setosa']
#  ['5.7' '4.4' '1.5' '0.4' 'Iris-setosa']
#  ['5.4' '3.9' '1.3' '0.4' 'Iris-setosa']
#  ['5.1' '3.5' '1.4' '0.3' 'Iris-setosa']
#  ['5.7' '3.8' '1.7' '0.3' 'Iris-setosa']
#  ['5.1' '3.8' '1.5' '0.3' 'Iris-setosa']
#  ['5.4' '3.4' '1.7' '0.2' 'Iris-setosa']
# ...

# %% [markdown]
# 8. Find the max, min, mean and standard deviation for the columns of the iris and store the results in the arrays iris_max, iris_min, iris_avg, iris_std, iris_ var respectively. The results must be rounded to not more than two decimal places

# %%
iris=np.loadtxt("iris.data",delimiter=",",dtype='str')
iris=iris[:,:4]
iris=np.array(iris,dtype=float)
iris_max=np.max(iris,axis=0)
print("Maximum:",iris_max)
iris_min=np.min(iris,axis=0)
print("Minimum:",iris_min)
iris_avg=np.round(np.mean(iris,axis=0),2)
print("Average:",iris_avg)
iris_std=np.round(np.std(iris,axis=0),2)
print("Standard Deviation:",iris_std)
iris_var=np.round(iris_std**2,2)
print("Variance:",iris_var)
# Out:
# Maximum: [7.9 4.4 6.9 2.5]
# Minimum: [4.3 2.  1.  0.1]
# Average: [5.84 3.05 3.76 1.2 ]
# Standard Deviation: [0.83 0.43 1.76 0.76]
# Variance: [0.69 0.18 3.1  0.58]

# %% [markdown]
# 9.Similarly find the max, min, mean and standard deviation for the columns of the irisl, iris2 and iris3 and store the results in the arrays with appropriate names

# %%
iris1=np.array(iris1,dtype=float)
iris2=np.array(iris2,dtype=float)
iris3=np.array(iris3,dtype=float)
iris1_max=np.max(iris1,axis=0)
print("\tFOR IRIS 1\n")
print("Maximum:",iris1_max)
iris1_min=np.min(iris1,axis=0)
print("Minimum:",iris1_min)
iris1_avg=np.round(np.mean(iris1,axis=0),2)
print("Average:",iris1_avg)
iris1_std=np.round(np.std(iris1,axis=0),2)
print("Standard Deviation:",iris1_std)
iris1_var=np.round(iris1_std**2,2)
print("Variance:",iris1_var)
#iris2
print("\n\tFOR IRIS 2\n")
iris2_max=np.max(iris2,axis=0)
print("Maximum:",iris2_max)
iris2_min=np.min(iris2,axis=0)
print("Minimum:",iris2_min)
iris2_avg=np.round(np.mean(iris2,axis=0),2)
print("Average:",iris2_avg)
iris2_std=np.round(np.std(iris2,axis=0),2)
print("Standard Deviation:",iris2_std)
iris2_var=np.round(iris2_std**2,2)
print("Variance:",iris2_var)
print("\n\tFOR IRIS 3\n")
iris3_max=np.max(iris3,axis=0)
print("Maximum:",iris3_max)
iris3_min=np.min(iris3,axis=0)
print("Minimum:",iris3_min)
iris3_avg=np.round(np.mean(iris3,axis=0),2)
print("Average:",iris3_avg)
iris3_std=np.round(np.std(iris3,axis=0),2)
print("Standard Deviation:",iris3_std)
iris3_var=np.round(iris3_std**2,2)
print("Variance:",iris3_var)
# Out:
# 	FOR IRIS 1
#
# Maximum: [5.8 4.4 1.9 0.6]
# Minimum: [4.3 2.3 1.  0.1]
# Average: [5.01 3.42 1.46 0.24]
# Standard Deviation: [0.35 0.38 0.17 0.11]
# Variance: [0.12 0.14 0.03 0.01]
#
# 	FOR IRIS 2
#
# Maximum: [7.  3.4 5.1 1.8]
# Minimum: [4.9 2.  3.  1. ]
# Average: [5.94 2.77 4.26 1.33]
# Standard Deviation: [0.51 0.31 0.47 0.2 ]
# Variance: [0.26 0.1  0.22 0.04]
#
# 	FOR IRIS 3
#
# Maximum: [7.9 3.8 6.9 2.5]
# Minimum: [4.9 2.2 4.5 1.4]
# Average: [6.59 2.97 5.55 2.03]
# Standard Deviation: [0.63 0.32 0.55 0.27]
# Variance: [0.4  0.1  0.3  0.07]

# %% [markdown]
# 10. Check the minimum value for sepal length, sepal width, petal length and petal width of the three species in comparison to the minimum value of sepal length, sepal width, petal length and petal width for the data set as a whole and fill the table below with True if the species value is greater than the dataset value and False otherwise.

# %%
print("\t\t\tCOMPARISION TABLE")
n=iris1_min>iris_min,iris2_min>iris_min,iris3_min>iris_min
n=np.transpose(n)
c=["Sepal Length","Sepal Width","Petal Length","Petal Width"]
print("\t\tIris-Setosa\tIris-Versicolor\tIris-Virginica")
for i in range(len(n)):
    print(c[i],end="\t")
    for j in n[i]:
        print(j,end="\t\t")
    print("\n")
# Out:
# 			COMPARISION TABLE
# 		Iris-Setosa	Iris-Versicolor	Iris-Virginica
# Sepal Length	False		True		True
#
# Sepal Width	True		False		True
#
# Petal Length	False		True		True
#
# Petal Width	False		True		True

# %% [markdown]
# # Method 2
# 10. Check the minimum value for sepal length, sepal width, petal length and petal width of the three species in comparison to the minimum value of sepal length, sepal width, petal length and petal width for the data set as a whole and fill the table below with True if the species value is greater than the dataset value and False otherwise.

# %%
import numpy as np
iris = np.genfromtxt("iris.data", delimiter=",", dtype='str')
iris_data = iris[:, :4].astype(float)
#species column
species = iris[:, 4]
#minimum values for each species
#for iris-setosa
min_setosa_sl = np.min(iris_data[species == 'Iris-setosa', 0])
min_setosa_sw = np.min(iris_data[species == 'Iris-setosa', 1])
min_setosa_pl = np.min(iris_data[species == 'Iris-setosa', 2])
min_setosa_pw = np.min(iris_data[species == 'Iris-setosa', 3])
#for iris_versicolor
min_versi_sl = np.min(iris_data[species == 'Iris-versicolor', 0])
min_versi_sw = np.min(iris_data[species == 'Iris-versicolor', 1])
min_versi_pl = np.min(iris_data[species == 'Iris-versicolor', 2])
min_versi_pw = np.min(iris_data[species == 'Iris-versicolor', 3])
#for iris-virginica
min_vir_sl = np.min(iris_data[species == 'Iris-virginica', 0])
min_vir_sw = np.min(iris_data[species == 'Iris-virginica', 1])
min_vir_pl = np.min(iris_data[species == 'Iris-virginica', 2])
min_vir_pw = np.min(iris_data[species == 'Iris-virginica', 3])
#minimum values for whole dataset
min_dataset_sl = np.min(iris_data[:, 0])
min_dataset_sw = np.min(iris_data[:, 1])
min_dataset_pl = np.min(iris_data[:, 2])
min_dataset_pw = np.min(iris_data[:, 3])
# Print the comparison table
print("\t\t\tCOMPARISION TABLE ")
print("\t\tIris-setosa\tIris-versicolor\tIris-virginica\t")
print("Sepal Length\t",  min_setosa_sl > min_dataset_sl, "\t\t", min_versi_sl > min_dataset_sl, "\t\t", min_vir_sl > min_dataset_sl)
print("Sepal Width \t", min_setosa_sw > min_dataset_sw, "\t\t", min_versi_sw > min_dataset_sw, "\t\t", min_vir_sw > min_dataset_sw)
print("Petal Length\t", min_setosa_pl > min_dataset_pl, "\t\t", min_versi_pl > min_dataset_pl, "\t\t",  min_vir_pl > min_dataset_pl)
print("Petal Width \t", min_setosa_pw > min_dataset_pw, "\t\t", min_versi_pw > min_dataset_pw, "\t\t",  min_vir_pw > min_dataset_pw)
# Out:
# 			COMPARISION TABLE
# 		Iris-setosa	Iris-versicolor	Iris-virginica
# Sepal Length	 False 		 True 		 True
# Sepal Width 	 True 		 False 		 True
# Petal Length	 False 		 True 		 True
# Petal Width 	 False 		 True 		 True

# %% [markdown]
# 11. Compare Iris setosa's average sepal width to that of Iris virginica.

# %%
print("Comparision Result:")
if iris1_avg[1]>iris3_avg[1]:
    print("Iris Setosa has greater average sepal width than Iris Virginica i.e {}".format(iris1_avg[1]));
elif avg_set<avg_vir:
    print("Iris Virginica has greater average sepal width than Iris Setosa i.e {}".format(avg_vir));
else:
     print("Iris Virginica has same average sepal width of Iris Setosa i.e {}".format(avg_set));
# Out:
# Comparision Result:
# Iris Setosa has greater average sepal width than Iris Virginica i.e 3.42

# %% [markdown]
# 12. Compare Iris setosa's average petal length to that of Iris virginica.

# %%
print("Comparision Result:")
if iris1_avg[2]>iris3_avg[2]:
    print("Iris Setosa has greater average petal length than Iris Virginica i.e {}".format(iris1_avg[2]));
elif iris1_avg[2]<iris3_avg[2]:
    print("Iris Virginica has greater average petal length than Iris Setosa i.e {}".format(iris3_avg[2]));
else:
     print("Iris Virginica has same average petal length of Iris Setosa i.e {}".format(avg_set));
# Out:
# Comparision Result:
# Iris Virginica has greater average petal length than Iris Setosa i.e 5.55

# %% [markdown]
# 13. Compare Iris setosa's average petal width to that of Iris virginica.

# %%
print("Comparision Result:")
if iris1_avg[3]>iris3_avg[3]:
    print("Iris Setosa has greater average petal width than Iris Virginica i.e {}".format(iris1_avg[3]));
elif iris1_avg[3]<iris3_avg[3]:
    print("Iris Virginica has greater average petal width than Iris Setosa i.e {}".format(iris3_avg[3]));
else:
     print("Iris Virginica has same average petal width of Iris Setosa i.e {}".format(avg_set));
# Out:
# Comparision Result:
# Iris Virginica has greater average petal width than Iris Setosa i.e 2.03

# %%
14. Save the array iris_avg in a comma separated file named IrisMeanValues.txt on the hard disk

# %%
np.savetxt('IrisMeanValues.txt',iris_avg,delimiter=",")
print(iris_avg)
# Out:
# [5.84 3.05 3.76 1.2 ]

# %% [markdown]
# 15. Save the arrays iris_max,iris_avg,iris_min in a comma separated file named IrisStat.txt on the hard disk

# %%
stat=np.vstack((iris_max,iris_avg,iris_min))
np.savetxt('IrisStat.txt',stat,delimiter=",")
